# %% [markdown]
# # Módulo de integración entre Modulos 1, 2, 3 y 4

# %%
# Suponiendo que ya tienes las clases Producto y GestionProductos

inventario = GestionProductos()
inventario.registrar_producto("P001", "Laptop Lenovo", "Tecnología", 10, 2500.00)
inventario.registrar_producto("P002", "Mouse Logitech", "Accesorios", 20, 80.00)

# Instanciación de módulos
stock = ControlStock(inventario.productos)
entradas = EntradasInventario(inventario.productos)
salidas = SalidasInventario(inventario.productos)

# Uso del módulo de stock
stock.mostrar_stock_general()

# Registrar entrada
entradas.registrar_entrada("P001", 5, "Compra a proveedor")

# Registrar salida
salidas.registrar_salida("P002", 3, "Venta")

# Ver stock actualizado
stock.mostrar_stock_general()

# Ver historiales
entradas.mostrar_historial_entradas()
salidas.mostrar_historial_salidas()
